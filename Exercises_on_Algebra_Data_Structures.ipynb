# %% [markdown]
# 1.  **selesaikan soal berikut **

# %%
import numpy as np

# %%
# what is the transpose of this vector?
x = np.array([[25],
              [2],
              [-3],
              [-23]])

x_t = x.T
x_t
# Out:
# array([[ 25,   2,  -3, -23]])

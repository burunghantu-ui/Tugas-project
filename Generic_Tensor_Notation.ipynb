# %% [markdown]
# **1. jelaskan tentang perintah ini**

# %%
# images_pt = torch.zeros([32, 28, 28, 3])

print("perintah troch.zeros digunakan untuk membuat sebuah tensor bernilai 0 ")
print('dengan ukuran 32 data, lebar 28pixel, tinggi 28pixel, dan 3 channel (RGB),')
print('Tensor ini biasanya digunakan sebagai inisialisasi data atau sebagai placeholder')
print("dalam proses pengolahan citra menggunakan PyTorch.")
# Out:
# perintah troch.zeros digunakan untuk membuat sebuah tensor bernilai 0
# dengan ukuran 32 data, lebar 28pixel, tinggi 28pixel, dan 3 channel (RGB),
# Tensor ini biasanya digunakan sebagai inisialisasi data atau sebagai placeholder
# dalam proses pengolahan citra menggunakan PyTorch.

# %%
# 1
#buat variabel skalar x dan simpan suatu nilai skalar
x = 120
x
# Out:
# 25

# %%
# tampilkan tipe data dari x
type(x)

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 201
y
# Out:
# 201

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 226

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 1.20
x_float
# Out:
# 1.2

# %%
# jumlahkan x_float dengan y
x_float = 1.20
float_sum = x_float + y
float_sum
# Out:
# 226.0

# %%
# tampilkan tipe data dari x_float
type(float_sum)
# Out:
# float

# %%
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow
import tensorflow as tf

# %%
# 2
x_tf = tf.Variable(120, dtype=tf.int16) # dtype is optional
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=120>

# %%
# 2
y_tf = tf.Variable(201, dtype=tf.int16) # dtype is optional
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=201>

# %%
# 2
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=321>

# %%
# 2
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=321>

# %%
# 2
x_float_tf = tf.Variable(1.20)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=1.2000000476837158>

# %%
# 2
tf_sum = tf.add(y_tf, x_float_tf)
tf_sum
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /tmp/ipykernel_13167/1862409851.py in <cell line: 0>()
#       1 # 2
# ----> 2 tf_sum = tf.add(y_tf, x_float_tf)
#       3 tf_sum
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/weak_tensor_ops.py in wrapper(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# ...

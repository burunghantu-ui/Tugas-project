# %%
# 1
# - buat variabel skalar x dan simpan suatu nilai skalar

x = 120
x
# Out:
# 120

# %%
# - tampilkan tipe data dari x

type(x)
# Out:
# int

# %%
# - buat variabel skalar y dan simpan suatu nilai skalar

y = 201
y
# Out:
# 201

# %%
# - tampilkan tipe data dari y

type(y)
# Out:
# int

# %%
# - jumlahkan x+y

py_sum = x + y
py_sum
# Out:
# 321

# %%
# - buat variabel bernama x_float dan simpan suatu nilai desimal

x_float = 1.20
x_float
# Out:
# 1.2

# %%
# - jumlahkan x_float dengan y

x_float = 1.20
float_sum = x_float + y
float_sum
# Out:
# tensor(211.2000)

# %%
# - tampilkan tipe data dari x_float

type(float_sum)
# Out:
# float

# %%
# 2. lakukan tahapan pada soal 1 dengan menggunakan tensorflow

import tensorflow as tf

# %%
# - buat variabel skalar x dan simpan suatu nilai skalar menggunakan TF
#  - tampilkan tipe data dari x

x_tf = tf.Variable(120)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=120>

# %%
# - buat variabel skalar y dan simpan suatu nilai skalar menggunakan TF
#  - tampilkan tipe data dari y

y_tf = tf.Variable(201)
y_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=201>

# %%
# - jumlahkan x+y menggunakan TF

tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=321>

# %%
# - buat variabel bernama x_float dan simpan suatu nilai desimal menggunakan FT
# - tampilkan tipe data dari x_float

x_float_tf = tf.Variable(1.20)
x_float_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=1.2000000476837158>

# %%
# 3. lakukan tahapan pada soal 1 dengan menggunakan pytorch

import torch

# %%
# buat variabel skalar x dan simpan suatu nilai skalar menggunakan pytorch
# tampilkan tipe data dari x

x = torch.tensor(120, dtype=torch.int)
x
# Out:
# tensor(120, dtype=torch.int32)

# %%
# buat variabel skalar y dan simpan suatu nilai skalar menggunakan pytorch
# tampilkan tipe data dari y

y = torch.tensor(210, dtype=torch.int)
y
# Out:
# tensor(210, dtype=torch.int32)

# %%
# jumlahkan x+y menggunakan pytorch

torch_sum = x + y   # sintaks spesifik torch yang diperlukan tidak terdapat pada file bapak
torch_sum
# Out:
# tensor(330, dtype=torch.int32)

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal menggunakan pytorch

x_float = torch.tensor(1.20)
x_float
# Out:
# tensor(1.2000)

# %%
# tampilkan tipe data dari x_float menggunakan pytorch

x_float.dtype  # sintaks spesifik torch yang diperlukan tidak terdapat pada file bapak
# Out:
# torch.float32
